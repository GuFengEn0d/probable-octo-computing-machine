# %% [markdown]
# <a href="https://colab.research.google.com/github/GuFengEn0d/probable-octo-computing-machine/blob/main/Python_2_Basics%20kumar.niteen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/flights.csv')

# %%
df.head()
# Out:
#    Carrier   Status  Los Angeles  Phoenix  San Diego  San Francisco  Seattle
# 0   Alaska  on_time          497      221        212            503     1841
# 1   Alaska  delayed           62       12         20            102      305
# 2  am west  on_time          694     4840        383            320      201
# 3  am west  delayed          117      415         65            129       61

# %%
# Out:
# <bound method DataFrame.mean of    Carrier   Status  Los Angeles  Phoenix  San Diego  San Francisco  Seattle
# 0   Alaska  on_time          497      221        212            503     1841
# 1   Alaska  delayed           62       12         20            102      305
# 2  am west  on_time          694     4840        383            320      201
# 3  am west  delayed          117      415         65            129       61>

# %%
wh_df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/refs/heads/master/Python/weight-height.csv')

# %%
wh_df.head(10)
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801
# 5   Male  67.253016  152.212156
# 6   Male  68.785081  183.927889
# 7   Male  68.348516  167.971110
# 8   Male  67.018950  175.929440
# 9   Male  63.456494  156.399676

# %%
wh_df.tail(10)
# Out:
#       Gender     Height      Weight
# 9990  Female  63.179498  141.266100
# 9991  Female  62.636675  102.853563
# 9992  Female  62.077832  138.691680
# 9993  Female  60.030434   97.687432
# 9994  Female  59.098250  110.529686
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
wh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
wh_df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
wh_df.shape
# Out:
# (10000, 3)

# %%
wh_df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
wh_df['Height'].mean()
# Out:
# 66.36755975482124

# %%
wh_df.plot.scatter(x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
wh_df.plot(kind='hist', x='Height')
# Out:
# <Axes: ylabel='Frequency'>

# %%
wh_df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
wh_df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
wh_df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# Find the descriptive statistics for both genders separately

# %%
wh_male_df = wh_df[wh_df['Gender'] == 'Male']

# %%
wh_male_df.describe()
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean     69.026346   187.020621
# std       2.863362    19.781155
# min      58.406905   112.902939
# 25%      67.174679   173.887767
# 50%      69.027709   187.033546
# 75%      70.988744   200.357802
# max      78.998742   269.989699

# %%
wh_male_df.plot.scatter(x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
wh_male_df.plot(kind='hist', x='Height')
wh_df.plot(kind='hist', x='Height')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_311_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
# Out:
# <ipython-input-34-85d5be1ab2ea>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_311_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')

# %%
data_311_df.head()
# Out:
#    Unique Key   Created Date      Closed Date Agency  Complaint Type  \
# 0    42680103  5/1/2019 0:00  5/16/2019 21:45    DEP    Water System
# 1    42530481  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 2    42527619  5/1/2019 0:00   5/13/2019 0:00  DOHMH  Food Poisoning
# 3    42526597  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 4    42526595  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
#
#                 Location Type Incident Zip             Incident Address  \
# 0                         NaN      11420.0            127-16 111 AVENUE
# 1  Restaurant/Bar/Deli/Bakery      10011.0         207 WEST   14 STREET
# 2  Restaurant/Bar/Deli/Bakery      10025.0                2664 BROADWAY
# 3  Restaurant/Bar/Deli/Bakery      11208.0  624 SOUTH CONDUIT BOULEVARD
# 4  Restaurant/Bar/Deli/Bakery      11106.0              31-91 21 STREET
#
#                Street Name Address Type  ... Landmark Facility Type  Status  \
# ...
