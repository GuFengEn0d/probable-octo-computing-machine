# %% [markdown]
# <a href="https://colab.research.google.com/github/GuFengEn0d/probable-octo-computing-machine/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/flights.csv")
df.head()
# Out:
#    Carrier   Status  Los Angeles  Phoenix  San Diego  San Francisco  Seattle
# 0   Alaska  on_time          497      221        212            503     1841
# 1   Alaska  delayed           62       12         20            102      305
# 2  am west  on_time          694     4840        383            320      201
# 3  am west  delayed          117      415         65            129       61

# %%
df.head(10)
# Out:
#    Carrier   Status  Los Angeles  Phoenix  San Diego  San Francisco  Seattle
# 0   Alaska  on_time          497      221        212            503     1841
# 1   Alaska  delayed           62       12         20            102      305
# 2  am west  on_time          694     4840        383            320      201
# 3  am west  delayed          117      415         65            129       61

# %%
df.tail()
# Out:
#    Carrier   Status  Los Angeles  Phoenix  San Diego  San Francisco  Seattle
# 0   Alaska  on_time          497      221        212            503     1841
# 1   Alaska  delayed           62       12         20            102      305
# 2  am west  on_time          694     4840        383            320      201
# 3  am west  delayed          117      415         65            129       61

# %%
df.count()
# Out:
# Carrier          4
# Status           4
# Los Angeles      4
# Phoenix          4
# San Diego        4
# San Francisco    4
# Seattle          4
# dtype: int64

# %%
df.max()
df.min()
# Out:
# Carrier           Alaska
# Status           delayed
# Los Angeles           62
# Phoenix               12
# San Diego             20
# San Francisco        102
# Seattle               61
# dtype: object

# %%
wh_df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/refs/heads/master/Python/weight-height.csv')

# %%
wh_df.head(20)
# Out:
#    Gender     Height      Weight
# 0    Male  73.847017  241.893563
# 1    Male  68.781904  162.310473
# 2    Male  74.110105  212.740856
# 3    Male  71.730978  220.042470
# 4    Male  69.881796  206.349801
# 5    Male  67.253016  152.212156
# 6    Male  68.785081  183.927889
# 7    Male  68.348516  167.971110
# 8    Male  67.018950  175.929440
# 9    Male  63.456494  156.399676
# 10   Male  71.195382  186.604926
# 11   Male  71.640805  213.741169
# 12   Male  64.766329  167.127461
# 13   Male  69.283070  189.446181
# 14   Male  69.243732  186.434168
# 15   Male  67.645620  172.186930
# 16   Male  72.418317  196.028506
# 17   Male  63.974326  172.883470
# 18   Male  69.640060  185.983958
# 19   Male  67.936005  182.426648

# %%
wh_df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
wh_df.shape
# Out:
# (10000, 3)

# %%
wh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
wh_df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
wh_df['Height'].mean()
# Out:
# 66.36755975482124

# %%
wh_df.plot.scatter(x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
wh_df.plot(kind='hist', y='Height')
# Out:
# <Axes: ylabel='Frequency'>

# %%
wh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
wh_df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
wh_male_df = wh_df[wh_df['Gender'] == 'Male']

# %%
data_311_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
data_311_df.head(20)
# Out:
# <ipython-input-133-62a99319af6c>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_311_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
#     Unique Key   Created Date      Closed Date Agency  \
# 0     42680103  5/1/2019 0:00  5/16/2019 21:45    DEP
# 1     42530481  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 2     42527619  5/1/2019 0:00   5/13/2019 0:00  DOHMH
# 3     42526597  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 4     42526595  5/1/2019 0:00    5/2/2019 0:00  DOHMH
# 5     42524590  5/1/2019 0:00    5/1/2019 0:00  DOHMH
# 6     42530673  5/1/2019 0:00   5/1/2019 15:22  DOHMH
# 7     42529368  5/1/2019 0:00   5/1/2019 14:22  DOHMH
# 8     42526596  5/1/2019 0:00   5/1/2019 14:53  DOHMH
# 9     42519734  5/1/2019 0:00   5/1/2019 11:23  DOHMH
# 10    42613472  5/1/2019 0:00              NaN    DEP
# ...

# %%
data_311_df.tail(40)
# Out:
#        Unique Key    Created Date      Closed Date Agency  \
# 69597    42625305  5/9/2019 23:49   5/10/2019 2:04   NYPD
# 69598    42628708  5/9/2019 23:49   5/10/2019 1:31   NYPD
# 69599    42630973  5/9/2019 23:49   5/10/2019 2:27   NYPD
# 69600    42633251  5/9/2019 23:49   5/10/2019 1:31   NYPD
# 69601    42631524  5/9/2019 23:50   5/10/2019 0:10    DEP
# 69602    42631900  5/9/2019 23:50   5/10/2019 3:43   NYPD
# 69603    42624807  5/9/2019 23:52   5/10/2019 2:22   NYPD
# 69604    42626474  5/9/2019 23:52   5/10/2019 2:46   NYPD
# 69605    42624878  5/9/2019 23:52   5/10/2019 6:54   NYPD
# 69606    42630681  5/9/2019 23:53   5/10/2019 7:08   NYPD
# 69607    42632147  5/9/2019 23:53   5/10/2019 0:12   NYPD
# 69608    42631456  5/9/2019 23:55  5/10/2019 22:15    DEP
# 69609    42628755  5/9/2019 23:55   5/10/2019 2:25   NYPD
# 69610    42626273  5/9/2019 23:56              NaN    TLC
# 69611    42631926  5/9/2019 23:56   5/10/2019 8:01   NYPD
# ...

# %%
data_311_df.describe()
# Out:
#          Unique Key           BBL      Latitude     Longitude
# count  6.963700e+04  5.570200e+04  65634.000000  65634.000000
# mean   4.260307e+07  2.869652e+09     40.723149    -73.924517
# std    5.269818e+04  1.184250e+09      0.083621      0.085089
# min    4.251278e+07  0.000000e+00     40.500025    -74.252279
# 25%    4.258004e+07  2.030690e+09     40.664461    -73.972161
# 50%    4.260019e+07  3.034830e+09     40.716443    -73.929758
# 75%    4.262095e+07  4.023330e+09     40.780783    -73.874064
# max    4.297343e+07  5.080480e+09     40.912869    -73.700597

# %%
data_311_df['Latitude'].mean()
# Out:
# 40.72314893130664

# %%
data_311_df.plot.scatter(x='Latitude', y='Longitude')
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>

# %%
data_311_df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Location Type', 'Incident Zip', 'Incident Address', 'Street Name',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Description', 'BBL', 'Borough', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
data_311_df.count()
# Out:
# Unique Key                69637
# Created Date              69637
# Closed Date               64626
# Agency                    69637
# Complaint Type            69637
# Location Type             53978
# Incident Zip              67389
# Incident Address          59033
# Street Name               59032
# Address Type              68307
# City                      67416
# Landmark                     16
# Facility Type             24081
# Status                    69637
# Due Date                  32839
# Resolution Description    63579
# BBL                       55702
# Borough                   69637
# Latitude                  65634
# Longitude                 65634
# Location                  65634
# dtype: int64

# %%
data_311_df.plot(kind='hist', y='Latitude')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_311_manhattan_df = data_311_df[data_311_df['Borough'] == 'Manhattan']

# %% [markdown]
# which borough has more complaints

# %%
data_311_complaints_df = data_311_df.groupby('Borough').count()

# %%
data_311_complaints_df
# Out:
#                Unique Key  Created Date  Closed Date  Agency  Complaint Type  \
# Borough
# BRONX               10925         10925        10351   10925           10925
# BROOKLYN            22247         22247        20547   22247           22247
# MANHATTAN           13133         13133        11819   13133           13133
# QUEENS              18623         18623        17549   18623           18623
# STATEN ISLAND        3848          3848         3608    3848            3848
# Unspecified           861           861          752     861             861
#
#                Location Type  Incident Zip  Incident Address  Street Name  \
# Borough
# BRONX                   9117         10589              9550         9550
# BROOKLYN               17511         21922             19508        19508
# MANHATTAN               9945         12693             11039        11039
# QUEENS                 13905         18209             15601        15601
# ...

# %%
data_311_df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Location Type', 'Incident Zip', 'Incident Address', 'Street Name',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Description', 'BBL', 'Borough', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
data_311_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-524dc6fb9fde> in <cell line: 1>()
# ----> 1 data_311_complaints_agencys_df
#
# NameError: name 'data_311_complaints_agencys_df' is not defined
